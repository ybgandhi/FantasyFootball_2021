# %%
import pandas as pd

# %%
# Draft Sharks URL's

## half ppr ADP rankings
half_adp_url = "https://www.draftsharks.com/adp/half"

# %%
adp_half_tables = pd.read_html(half_adp_url)
adp_half_tables
# Out:
# [              Positional Rank FF Nerds Avg. Draft Position  Bye Week  \
#  0    1. Christian McCaffreyRB             1.1 Show Trend »        13
#  1            2. Dalvin CookRB             1.2 Show Trend »         7
#  2          3. Derrick HenryRB             1.3 Show Trend »        13
#  3           4. Alvin KamaraRB             1.4 Show Trend »         6
#  4        5. Ezekiel ElliottRB             1.5 Show Trend »         7
#  ..                        ...                          ...       ...
#  389        390. Will DisslyTE           28.12 Show Trend »         9
#  390        391. Kellen MondQB           28.12 Show Trend »         7
#  391       392. Luke WillsonTE           28.12 Show Trend »         9
#  392       393. Duke JohnsonRB           28.12 Show Trend »         0
#  393        394. Chris EvansRB           28.12 Show Trend »        10
#
#       Consensus Points  DS Fantasy Points
#  0                 287              357.5
#  1                 276              300.5
#  2                 273              278.0
#  3                 233              281.5
#  4                 229              282.5
#  ..                ...                ...
#  389                44               44.5
#  390                13                0.0
#  391                 1                0.0
#  392                24               51.5
#  393                15               22.5
#
#  [394 rows x 5 columns]]

# %%
adp_half_df = adp_half_tables[0]
adp_half_df
# Out:
#               Positional Rank FF Nerds Avg. Draft Position  Bye Week  \
# 0    1. Christian McCaffreyRB             1.1 Show Trend »        13
# 1            2. Dalvin CookRB             1.2 Show Trend »         7
# 2          3. Derrick HenryRB             1.3 Show Trend »        13
# 3           4. Alvin KamaraRB             1.4 Show Trend »         6
# 4        5. Ezekiel ElliottRB             1.5 Show Trend »         7
# ..                        ...                          ...       ...
# 389        390. Will DisslyTE           28.12 Show Trend »         9
# 390        391. Kellen MondQB           28.12 Show Trend »         7
# 391       392. Luke WillsonTE           28.12 Show Trend »         9
# 392       393. Duke JohnsonRB           28.12 Show Trend »         0
# 393        394. Chris EvansRB           28.12 Show Trend »        10
#
#      Consensus Points  DS Fantasy Points
# 0                 287              357.5
# 1                 276              300.5
# 2                 273              278.0
# 3                 233              281.5
# 4                 229              282.5
# ..                ...                ...
# 389                44               44.5
# 390                13                0.0
# 391                 1                0.0
# 392                24               51.5
# 393                15               22.5
#
# [394 rows x 5 columns]

# %%
count = adp_half_df.count
print(count)
# Out:
# <bound method DataFrame.count of               Positional Rank FF Nerds Avg. Draft Position  Bye Week  \
# 0    1. Christian McCaffreyRB             1.1 Show Trend »        13
# 1            2. Dalvin CookRB             1.2 Show Trend »         7
# 2          3. Derrick HenryRB             1.3 Show Trend »        13
# 3           4. Alvin KamaraRB             1.4 Show Trend »         6
# 4        5. Ezekiel ElliottRB             1.5 Show Trend »         7
# ..                        ...                          ...       ...
# 389        390. Will DisslyTE           28.12 Show Trend »         9
# 390        391. Kellen MondQB           28.12 Show Trend »         7
# 391       392. Luke WillsonTE           28.12 Show Trend »         9
# 392       393. Duke JohnsonRB           28.12 Show Trend »         0
# 393        394. Chris EvansRB           28.12 Show Trend »        10
#
#      Consensus Points  DS Fantasy Points
# 0                 287              357.5
# 1                 276              300.5
# 2                 273              278.0
# 3                 233              281.5
# 4                 229              282.5
# ..                ...                ...
# 389                44               44.5
# 390                13                0.0
# 391                 1                0.0
# 392                24               51.5
# 393                15               22.5
#
# [394 rows x 5 columns]>

# %%
# set up dataframe 
adp_half_df["DF Rank"] = adp_half_df["Positional Rank"].astype(str).str[0:2]
adp_half_df["ADP Avg."] = adp_half_df["FF Nerds Avg. Draft Position"].astype(str).str[0:4]
adp_half_df["Position"] = adp_half_df["Positional Rank"].astype(str).str[-2:]
adp_half_df["Position"] = adp_half_df["Position"].replace({"EF":"DEF"})
adp_half_df = adp_half_df.loc[0:250:]

adp_half_df
# Out:
#                Positional Rank FF Nerds Avg. Draft Position  Bye Week  \
# 0     1. Christian McCaffreyRB             1.1 Show Trend »        13
# 1             2. Dalvin CookRB             1.2 Show Trend »         7
# 2           3. Derrick HenryRB             1.3 Show Trend »        13
# 3            4. Alvin KamaraRB             1.4 Show Trend »         6
# 4         5. Ezekiel ElliottRB             1.5 Show Trend »         7
# ..                         ...                          ...       ...
# 246     247. Dallas CowboysDEF            21.9 Show Trend »         7
# 247       248. Josh ReynoldsWR           21.10 Show Trend »        13
# 248         249. Denzel MimsWR           21.11 Show Trend »         6
# 249  250. Green Bay PackersDEF           21.12 Show Trend »        13
# 250      251. Adam HumphriesWR            22.1 Show Trend »         9
#
#      Consensus Points  DS Fantasy Points DF Rank ADP Avg. Position
# 0                 287              357.5      1.     1.1        RB
# 1                 276              300.5      2.     1.2        RB
# 2                 273              278.0      3.     1.3        RB
# 3                 233              281.5      4.     1.4        RB
# 4                 229              282.5      5.     1.5        RB
# ..                ...                ...     ...      ...      ...
# 246                91               84.0      24     21.9      DEF
# 247                55               78.5      24     21.1       WR
# 248                60               58.5      24     21.1       WR
# 249               100               88.0      25     21.1      DEF
# 250                45               51.0      25     22.1       WR
#
# [251 rows x 8 columns]

# %%
# insert for loop for position webscrape
## eposition_url = "https://www.draftsharks.com/preseason-rankings/"+ position +"/half-ppr"
## postion =

# %%
adp_half_df_new = adp_half_df_new.locsitional Rank"].
# Out:
#     DF Rank ADP Avg.            Positional Rank Position  Bye Week  \
# 0        1.     1.1    1. Christian McCaffreyRB       RB        13
# 1        2.     1.2            2. Dalvin CookRB       RB         7
# 2        3.     1.3          3. Derrick HenryRB       RB        13
# 3        4.     1.4           4. Alvin KamaraRB       RB         6
# 4        5.     1.5        5. Ezekiel ElliottRB       RB         7
# ..      ...      ...                        ...      ...       ...
# 246      24     21.9     247. Dallas CowboysDEF      DEF         7
# 247      24     21.1       248. Josh ReynoldsWR       WR        13
# 248      24     21.1         249. Denzel MimsWR       WR         6
# 249      25     21.1  250. Green Bay PackersDEF      DEF        13
# 250      25     22.1      251. Adam HumphriesWR       WR         9
#
#      Consensus Points  DS Fantasy Points
# 0                 287              357.5
# 1                 276              300.5
# 2                 273              278.0
# 3                 233              281.5
# 4                 229              282.5
# ..                ...                ...
# 246                91               84.0
# 247                55               78.5
# 248                60               58.5
# 249               100               88.0
# 250                45               51.0
#
# [251 rows x 7 columns]

# %%
first_nine  = 10
ten_to_99 = 100
for x in range(len(adp_half_df_new)):
    print(adp_half_df_new.iloc)
adp_half_df_new
# Out:
#     DF Rank ADP Avg.            Positional Rank Position  Bye Week  \
# 0        1.     1.1    1. Christian McCaffreyRB       RB        13
# 1        2.     1.2            2. Dalvin CookRB       RB         7
# 2        3.     1.3          3. Derrick HenryRB       RB        13
# 3        4.     1.4           4. Alvin KamaraRB       RB         6
# 4        5.     1.5        5. Ezekiel ElliottRB       RB         7
# ..      ...      ...                        ...      ...       ...
# 246      24     21.9     247. Dallas CowboysDEF      DEF         7
# 247      24     21.1       248. Josh ReynoldsWR       WR        13
# 248      24     21.1         249. Denzel MimsWR       WR         6
# 249      25     21.1  250. Green Bay PackersDEF      DEF        13
# 250      25     22.1      251. Adam HumphriesWR       WR         9
#
#      Consensus Points  DS Fantasy Points                     Name
# 0                 287              357.5    Christian McCaffreyRB
# 1                 276              300.5            Dalvin CookRB
# 2                 273              278.0          Derrick HenryRB
# 3                 233              281.5           Alvin KamaraRB
# 4                 229              282.5        Ezekiel ElliottRB
# ..                ...                ...                      ...
# 246                91               84.0     7. Dallas CowboysDEF
# 247                55               78.5       8. Josh ReynoldsWR
# 248                60               58.5         9. Denzel MimsWR
# 249               100               88.0  0. Green Bay PackersDEF
# 250                45               51.0      1. Adam HumphriesWR
#
# [251 rows x 8 columns]
