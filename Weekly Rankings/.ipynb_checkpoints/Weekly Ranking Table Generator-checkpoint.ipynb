# %%
import pandas as pd
import os
import numpy as np

# %%
weeks = ["2","3"]

# %%
csv_part1 = "inputs/Half_PPR_Week_"
csv_part2 = "_FLX_Rankings.csv"

# %%
loop_df = pd.DataFrame(columns=['Team','Name','Position'])

for x in weeks:
    
    csv_full = csv_part1 + x + csv_part2
    raw_df = pd.read_csv(csv_full)
    df = raw_df
    ###
    #ETL
    ##
    ## line of script to create Position Column
    df["Position"] = df["POS"].str.replace('[^a-zA-Z]','')
    ## line of script to create Position Rank Column
    df["Position Rank"] = df["POS"].str.extract('(\d+)',expand=False)
    ## Rename columns
    df = df.rename(columns={'TEAM':'Team','BEST':'Ceiling',
                        'WORST':'Floor','AVG.':'Average',
                        'STD.DEV':'Standard Deviation',
                       'PLAYER NAME':'Name'})
    ## new df to export into csv
    new_df = df[["RK","Team","Name","Position","Position Rank","Ceiling","Average","Floor","Standard Deviation"]]
    new_df = new_df.set_index("RK")
    new_df.to_csv("outputs/Week_" + x + "_Half_FLX.csv")
    new_df.to_html("outputs/Week_" + x + "_Half_FLX.html")
    new_df.to_json("outputs/Week_" + x + "_Half_FLX.json")
    
    #loop_df = loop_df.merge(new_df, on=['Team','Name','Position'])
    #loop_df = loop_df.rename(columns={"Position Rank_x":"Week "+x+" Position Rank",
     #                                "Ceiling_x":"Week "+x+" Ceiling",
      #                               "Average_x": "Week "+x+" Average",
       #                              "Floor_x": "Week "+x+" Floor",
        #                             "Standard Deviation_x": "Week "+x+" SD" })
    
    
    ###
    print(new_df)
    print(csv_full)
# Out:
#     Team                 Name Position Position Rank  Ceiling  Average  Floor  \
# RK
# 1    CAR  Christian McCaffrey       RB             1        1      1.3      8
# 2    MIN          Dalvin Cook       RB             2        1      2.8      8
# 3     NO         Alvin Kamara       RB             3        1      3.6      8
# 4     GB        Davante Adams       WR             1        3      4.5     17
# 5     KC          Tyreek Hill       WR             2        4      5.8     20
# ..   ...                  ...      ...           ...      ...      ...    ...
# 425   NE       Matthew Slater       WR           183      373    391.0    419
# 426  DET        Jared Pinkney       TE           112      369    383.5    398
# 427  CHI       Nsimba Webster       WR           184      362    395.0    418
# 428   TB          Deon Yelder       TE           113      373    392.0    411
# 429  CIN        Trenton Irwin       WR           185      405    407.0    409
#
#      Standard Deviation
# RK
# 1                   1.0
# 2                   1.7
# 3                   1.7
# 4                   1.6
# 5                   2.6
# ..                  ...
# 425                20.1
# 426                14.5
# 427                23.9
# 428                19.0
# 429                 2.0
#
# [429 rows x 8 columns]
# inputs/Half_PPR_Week_2_FLX_Rankings.csv
#     Team                 Name Position Position Rank  Ceiling  Average  Floor  \
# RK
# 1    CAR  Christian McCaffrey       RB             1        1      1.0      1
# 2    MIN          Dalvin Cook       RB             2        2      2.3      4
# 3    TEN        Derrick Henry       RB             3        2      2.8      3
# 4     GB        Davante Adams       WR             1        5      5.6      9
# 5     KC          Tyreek Hill       WR             2        5      5.9      9
# ..   ...                  ...      ...           ...      ...      ...    ...
# 309   TB        Scotty Miller       WR           128      287    309.0    331
# 310  BAL        Tylan Wallace       WR           129      289    317.0    345
# 311  MIN       Dede Westbrook       WR           130      297    302.5    308
# 312  ARI        Andy Isabella       WR           131      296    314.0    332
# 313  DAL          Simi Fehoko       WR           132      302    315.0    328
#
#      Standard Deviation
# RK
# 1                   0.0
# 2                   0.6
# 3                   0.4
# 4                   1.0
# 5                   0.8
# ..                  ...
# 309                22.0
# 310                28.0
# 311                 5.5
# 312                18.0
# 313                13.0
#
# [313 rows x 8 columns]
# inputs/Half_PPR_Week_3_FLX_Rankings.csv
# <ipython-input-4-940aae31173c>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Position"] = df["POS"].str.replace('[^a-zA-Z]','')
# <ipython-input-4-940aae31173c>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["Position"] = df["POS"].str.replace('[^a-zA-Z]','')

# %%
week_2 = pd.read_json("outputs/Week_2_Half_FLX.json")
week_3 = pd.read_json("outputs/Week_3_Half_FLX.json")
week_4 = pd.read_json("outputs/Week_4_Half_FLX.json")

# %%
df_list = [week_2, week_3, week_4]
merged = pd.concat(df_list)
merged.to_json("outputs/merged.json")
merged.to_html("outputs/merged.html")
# Out:
#     Team                  Name Position  Position Rank  Ceiling  Average  \
# 1    CAR   Christian McCaffrey       RB              1        1      1.3
# 2    MIN           Dalvin Cook       RB              2        1      2.8
# 3     NO          Alvin Kamara       RB              3        1      3.6
# 4     GB         Davante Adams       WR              1        3      4.5
# 5     KC           Tyreek Hill       WR              2        4      5.8
# ..   ...                   ...      ...            ...      ...      ...
# 327  MIN  Ihmir Smith-Marsette       WR            142      314    335.0
# 328  LAR           Tutu Atwell       WR            143      315    347.0
# 329  TEN          Racey McMath       WR            144      318    334.0
# 330  HOU         Brevin Jordan       TE             81      319    356.0
# 331  WAS            John Bates       TE             82      320    362.5
#
#      Floor  Standard Deviation
# 1        8                 1.0
# 2        8                 1.7
# 3        8                 1.7
# 4       17                 1.6
# 5       20                 2.6
# ..     ...                 ...
# 327    356                21.0
# 328    379                32.0
# 329    350                16.0
# 330    393                37.0
# 331    405                42.5
#
# [1073 rows x 8 columns]

# %%
# Out:
# [    Team                 Name Position  Position Rank  Ceiling  Average  \
#  1    CAR  Christian McCaffrey       RB              1        1      1.3
#  2    MIN          Dalvin Cook       RB              2        1      2.8
#  3     NO         Alvin Kamara       RB              3        1      3.6
#  4     GB        Davante Adams       WR              1        3      4.5
#  5     KC          Tyreek Hill       WR              2        4      5.8
#  ..   ...                  ...      ...            ...      ...      ...
#  425   NE       Matthew Slater       WR            183      373    391.0
#  426  DET        Jared Pinkney       TE            112      369    383.5
#  427  CHI       Nsimba Webster       WR            184      362    395.0
#  428   TB          Deon Yelder       TE            113      373    392.0
#  429  CIN        Trenton Irwin       WR            185      405    407.0
#
#       Floor  Standard Deviation
#  1        8                 1.0
#  2        8                 1.7
#  3        8                 1.7
#  4       17                 1.6
#  5       20                 2.6
#  ..     ...                 ...
#  425    419                20.1
#  426    398                14.5
#  427    418                23.9
#  428    411                19.0
#  429    409                 2.0
#
#  [429 rows x 8 columns],
#      Team                 Name Position  Position Rank  Ceiling  Average  \
#  1    CAR  Christian McCaffrey       RB              1        1      1.0
#  2    MIN          Dalvin Cook       RB              2        2      2.3
#  3    TEN        Derrick Henry       RB              3        2      2.8
#  4     GB        Davante Adams       WR              1        5      5.6
#  5     KC          Tyreek Hill       WR              2        5      5.9
#  ..   ...                  ...      ...            ...      ...      ...
#  309   TB        Scotty Miller       WR            128      287    309.0
#  310  BAL        Tylan Wallace       WR            129      289    317.0
#  311  MIN       Dede Westbrook       WR            130      297    302.5
#  312  ARI        Andy Isabella       WR            131      296    314.0
#  313  DAL          Simi Fehoko       WR            132      302    315.0
#
#       Floor  Standard Deviation
#  1        1                 0.0
#  2        4                 0.6
#  3        3                 0.4
#  4        9                 1.0
#  5        9                 0.8
#  ..     ...                 ...
#  309    331                22.0
#  310    345                28.0
#  311    308                 5.5
#  312    332                18.0
#  313    328                13.0
#
#  [313 rows x 8 columns],
#      Team                  Name Position  Position Rank  Ceiling  Average  \
#  1    TEN         Derrick Henry       RB              1        1      1.0
#  2     NO          Alvin Kamara       RB              2        2      2.3
#  3    LAC         Austin Ekeler       RB              3        2      3.8
#  4     GB         Davante Adams       WR              1        3      4.5
#  5    LAR           Cooper Kupp       WR              2        4      6.3
#  ..   ...                   ...      ...            ...      ...      ...
#  327  MIN  Ihmir Smith-Marsette       WR            142      314    335.0
#  328  LAR           Tutu Atwell       WR            143      315    347.0
#  329  TEN          Racey McMath       WR            144      318    334.0
#  330  HOU         Brevin Jordan       TE             81      319    356.0
#  331  WAS            John Bates       TE             82      320    362.5
#
#       Floor  Standard Deviation
#  1        1                 0.0
#  2        3                 0.5
#  3       11                 2.3
#  4        9                 1.4
#  5       10                 2.0
#  ..     ...                 ...
#  327    356                21.0
#  328    379                32.0
#  329    350                16.0
#  330    393                37.0
#  331    405                42.5
#
#  [331 rows x 8 columns]]

# %%
#loop_df = loop_df.merge(new_df, on=['Team','Name','Position'])
#loop_df = loop_df.rename(columns={"Position Rank_x":"Week "+x+" Position Rank",
#                                     "Ceiling_x":"Week "+x+" Ceiling",
#                                     "Average_x": "Week "+x+" Average",
#                                     "Floor_x": "Week "+x+" Floor",
#                                     "Standard Deviation_x": "Week "+x+" SD" })

# %%
#loop_df.head()
